# %% [markdown]
#  Interior Delta ML (TT dataset)

# %% [markdown]
# # Preprosesing

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow import keras
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
Alk_path="inputs/Alkalinity.csv"
Br_path="inputs/Br.csv"
Ca_path="inputs/Ca.csv"
Cl_path="inputs/Cl.csv"
K_path="inputs/K.csv"
Mg_path="inputs/Mg.csv"
Na_path="inputs/Na.csv"
SO4_path="inputs/SO4.csv"
TDS_path="inputs/TDS.csv"

Alkalinity= pd.read_csv(Alk_path)
Br= pd.read_csv(Br_path)
Ca= pd.read_csv(Ca_path)
Cl= pd.read_csv(Cl_path)
K= pd.read_csv(K_path)
Mg= pd.read_csv(Mg_path)
Na= pd.read_csv(Na_path)
SO4= pd.read_csv(SO4_path)
TDS= pd.read_csv(TDS_path)

Alkalinity= pd.DataFrame(Alkalinity)
Br= pd.DataFrame(Br)
Ca= pd.DataFrame(Ca)
Cl= pd.DataFrame(Cl)
K = pd.DataFrame(K)
Mg= pd.DataFrame(Mg)
Na= pd.DataFrame(Na)
SO4= pd.DataFrame(SO4)
TDS= pd.DataFrame(TDS)

Alkalinity.dropna(subset=["Sacramento X2"], inplace=True)
Br.dropna(axis=0, subset=["Sacramento X2"], inplace=True)
Ca.dropna(subset=["Sacramento X2"], inplace=True)
Cl.dropna(subset=["Sacramento X2"], inplace=True)
K.dropna(subset=["Sacramento X2"], inplace=True)
Mg.dropna(subset=["Sacramento X2"], inplace=True)
Na.dropna(subset=["Sacramento X2"], inplace=True)
SO4.dropna(subset=["Sacramento X2"], inplace=True)
TDS.dropna(subset=["Sacramento X2"], inplace=True)

Alkalinity["Collection Date"] = pd.to_datetime(df["Collection Date"])
Alkalinity["Long Station Name"] = Alkalinity["Long Station Name"].astype("category")
Alkalinity["Location"] = Alkalinity["Location"].astype("category")
df["Area"] = df["Area"].astype("category")
df.dropna(subset=["Sacramento X2"], inplace=True)
df.sort_values("Collection Date", inplace=True)

# %%
sns.heatmap(TDS.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
X_alk = Alkalinity.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_alk = Alkalinity.iloc[:, 3].values

X_Br = Br.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_Br = Br.iloc[:, 3].values

X_Ca = Ca.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_Ca = Ca.iloc[:, 3].values

X_Cl = Cl.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_Cl = Cl.iloc[:, 3].values

X_K = K.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_K = K.iloc[:, 3].values

X_Mg = Mg.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_Mg = Mg.iloc[:, 3].values

X_Na = Na.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_Na = Na.iloc[:, 3].values

X_SO4 = SO4.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_SO4 = SO4.iloc[:, 3].values

X_TDS = TDS.loc[:, ['EC', 'Sacramento X2','WYT']].values
y_TDS = TDS.iloc[:, 3].values

# %% [markdown]
# ## Encoding categorical data (WYT)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_alk = np.array(ct.fit_transform(X_alk))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_Br = np.array(ct.fit_transform(X_Br))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_Ca = np.array(ct.fit_transform(X_Ca))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_Cl = np.array(ct.fit_transform(X_Cl))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_K = np.array(ct.fit_transform(X_K))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_Mg = np.array(ct.fit_transform(X_Mg))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_Na = np.array(ct.fit_transform(X_Na))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_SO4 = np.array(ct.fit_transform(X_SO4))

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
X_TDS = np.array(ct.fit_transform(X_TDS))

# %%
p_alk=round(len(X_alk)*0.8)
X_alk_train=X_alk[0:p_alk,]
y_alk_train=y_alk[0:p_alk,]
X_alk_test=X_alk[(p_alk+1):len(X_alk),]
y_alk_test=y_alk[(p_alk+1):len(X_alk),]

p_Br=round(len(X_Br)*0.8)
X_Br_train=X_Br[0:p_Br,]
y_Br_train=y_Br[0:p_Br,]
X_Br_test=X_Br[(p_Br+1):len(X_Br),]
y_Br_test=y_Br[(p_Br+1):len(X_Br),]

p_Ca=round(len(X_Ca)*0.8)
X_Ca_train=X_Ca[0:p_Ca,]
y_Ca_train=y_Ca[0:p_Ca,]
X_Ca_test=X_Ca[(p_Ca+1):len(X_Ca),]
y_Ca_test=y_Ca[(p_Ca+1):len(X_Ca),]

p_Cl=round(len(X_Cl)*0.8)
X_Cl_train=X_Cl[0:p_Cl,]
y_Cl_train=y_Cl[0:p_Cl,]
X_Cl_test=X_Cl[(p_Cl+1):len(X_Cl),]
y_Cl_test=y_Cl[(p_Cl+1):len(X_Cl),]

p_K=round(len(X_K)*0.8)
X_K_train=X_K[0:p_K,]
y_K_train=y_K[0:p_K,]
X_K_test=X_K[(p_K+1):len(X_K),]
y_K_test=y_K[(p_K+1):len(X_K),]

p_Mg=round(len(X_Mg)*0.8)
X_Mg_train=X_Mg[0:p_Mg,]
y_Mg_train=y_Mg[0:p_Mg,]
X_Mg_test=X_Mg[(p_Mg+1):len(X_Mg),]
y_Mg_test=y_Mg[(p_Mg+1):len(X_Mg),]

p_Na=round(len(X_Na)*0.8)
X_Na_train=X_Na[0:p_Na,]
y_Na_train=y_Na[0:p_Na,]
X_Na_test=X_Na[(p_Na+1):len(X_Na),]
y_Na_test=y_Na[(p_Na+1):len(X_Na),]

p_SO4=round(len(X_SO4)*0.8)
X_SO4_train=X_SO4[0:p_SO4,]
y_SO4_train=y_SO4[0:p_SO4,]
X_SO4_test=X_SO4[(p_SO4+1):len(X_SO4),]
y_SO4_test=y_SO4[(p_SO4+1):len(X_SO4),]

p_TDS=round(len(X_TDS)*0.8)
X_TDS_train=X_TDS[0:p_TDS,]
y_TDS_train=y_TDS[0:p_TDS,]
X_TDS_test=X_TDS[(p_TDS+1):len(X_TDS),]
y_TDS_test=y_TDS[(p_TDS+1):len(X_TDS),]

# %%
X_TDS

# %%
print(X_TDS_train.shape)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#from sklearn.preprocessing import MinMaxScaler
#sc = MinMaxScaler(feature_range = (0, 1))
X_alk_train = sc.fit_transform(X_alk_train)
X_alk_test = sc.transform(X_alk_test)

X_Br_train = sc.fit_transform(X_Br_train)
X_Br_test = sc.transform(X_Br_test)

X_Ca_train = sc.fit_transform(X_Ca_train)
X_Ca_test = sc.transform(X_Ca_test)

X_Cl_train = sc.fit_transform(X_Cl_train)
X_Cl_test = sc.transform(X_Cl_test)

X_K_train = sc.fit_transform(X_K_train)
X_K_test = sc.transform(X_K_test)

X_Mg_train = sc.fit_transform(X_Mg_train)
X_Mg_test = sc.transform(X_Mg_test)

X_Na_train = sc.fit_transform(X_Na_train)
X_Na_test = sc.transform(X_Na_test)

X_SO4_train = sc.fit_transform(X_SO4_train)
X_SO4_test = sc.transform(X_SO4_test)

X_TDS_train = sc.fit_transform(X_TDS_train)
X_TDS_test = sc.transform(X_TDS_test)

# %% [markdown]
# # . ML

# %% [markdown]
# ## Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor_alk = LinearRegression()
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = LinearRegression()
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = LinearRegression()
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = LinearRegression()
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = LinearRegression()
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = LinearRegression()
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = LinearRegression()
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = LinearRegression()
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = LinearRegression()
regressor_TDS.fit(X_TDS_train, y_TDS_train)

# %%
y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %% [markdown]
# ## Training the SVR model

# %%
from sklearn.svm import SVR

regressor_alk = SVR(kernel = 'rbf')
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = SVR(kernel = 'rbf')
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = SVR(kernel = 'rbf')
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = SVR(kernel = 'rbf')
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = SVR(kernel = 'rbf')
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = SVR(kernel = 'rbf')
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = SVR(kernel = 'rbf')
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = SVR(kernel = 'rbf')
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = SVR(kernel = 'rbf')
regressor_TDS.fit(X_TDS_train, y_TDS_train)


y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %% [markdown]
# ## Training the Decision Tree Regression model

# %%
from sklearn.tree import DecisionTreeRegressor

regressor_alk = DecisionTreeRegressor(random_state = 0)
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = DecisionTreeRegressor(random_state = 0)
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = DecisionTreeRegressor(random_state = 0)
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = DecisionTreeRegressor(random_state = 0)
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = DecisionTreeRegressor(random_state = 0)
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = DecisionTreeRegressor(random_state = 0)
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = DecisionTreeRegressor(random_state = 0)
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = DecisionTreeRegressor(random_state = 0)
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = DecisionTreeRegressor(random_state = 0)
regressor_TDS.fit(X_TDS_train, y_TDS_train)


y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %% [markdown]
# ## Training the Random Forest Regression model

# %%
from sklearn.ensemble import RandomForestRegressor


regressor_alk = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor_TDS.fit(X_TDS_train, y_TDS_train)


y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

regressor_alk = GradientBoostingRegressor()
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = GradientBoostingRegressor()
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = GradientBoostingRegressor()
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = GradientBoostingRegressor()
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = GradientBoostingRegressor()
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = GradientBoostingRegressor()
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = GradientBoostingRegressor()
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = GradientBoostingRegressor()
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = GradientBoostingRegressor()
regressor_TDS.fit(X_TDS_train, y_TDS_train)


y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor

regressor_alk = AdaBoostRegressor()
regressor_alk.fit(X_alk_train, y_alk_train)

regressor_Br = AdaBoostRegressor()
regressor_Br.fit(X_Br_train, y_Br_train)

regressor_Ca = AdaBoostRegressor()
regressor_Ca.fit(X_Ca_train, y_Ca_train)

regressor_Cl = AdaBoostRegressor()
regressor_Cl.fit(X_Cl_train, y_Cl_train)

regressor_K = AdaBoostRegressor()
regressor_K.fit(X_K_train, y_K_train)

regressor_Mg = AdaBoostRegressor()
regressor_Mg.fit(X_Mg_train, y_Mg_train)

regressor_Na = AdaBoostRegressor()
regressor_Na.fit(X_Na_train, y_Na_train)

regressor_SO4 = AdaBoostRegressor()
regressor_SO4.fit(X_SO4_train, y_SO4_train)

regressor_TDS = AdaBoostRegressor()
regressor_TDS.fit(X_TDS_train, y_TDS_train)


y_pred_alk_test = regressor_alk.predict(X_alk_test)
y_pred_Br_test = regressor_Br.predict(X_Br_test)
y_pred_Ca_test = regressor_Ca.predict(X_Ca_test)
y_pred_Cl_test = regressor_Cl.predict(X_Cl_test)
y_pred_K_test = regressor_K.predict(X_K_test)
y_pred_Mg_test = regressor_Mg.predict(X_Mg_test)
y_pred_Na_test = regressor_Na.predict(X_Na_test)
y_pred_SO4_test = regressor_SO4.predict(X_SO4_test)
y_pred_TDS_test = regressor_TDS.predict(X_TDS_test)

y_pred_alk_train = regressor_alk.predict(X_alk_train)
y_pred_Br_train = regressor_Br.predict(X_Br_train)
y_pred_Ca_train = regressor_Ca.predict(X_Ca_train)
y_pred_Cl_train = regressor_Cl.predict(X_Cl_train)
y_pred_K_train = regressor_K.predict(X_K_train)
y_pred_Mg_train = regressor_Mg.predict(X_Mg_train)
y_pred_Na_train = regressor_Na.predict(X_Na_train)
y_pred_SO4_train = regressor_SO4.predict(X_SO4_train)
y_pred_TDS_train = regressor_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %% [markdown]
# ## ANN

# %%
ann_alk = tf.keras.models.Sequential()
ann_alk.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_alk.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_alk.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_alk.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_alk.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_alk.add(tf.keras.layers.Dense(units=1))
ann_alk.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_alk= ann_alk.fit(X_alk_train, y_alk_train, validation_split=0.33, batch_size = 16, epochs = 500)

y_pred_alk_test = ann_alk.predict(X_alk_test)
y_pred_alk_train = ann_alk.predict(X_alk_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))

# %%
ann_Br = tf.keras.models.Sequential()
ann_Br.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_Br.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Br.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Br.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Br.add(tf.keras.layers.Dense(units=5, activation='ELU'))

ann_Br.add(tf.keras.layers.Dense(units=1))
ann_Br.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_Br= ann_Br.fit(X_Br_train, y_Br_train, validation_split=0.33, batch_size = 16, epochs = 500)


y_pred_Br_test = ann_Br.predict(X_Br_test)

y_pred_Br_train = ann_Br.predict(X_Br_train)


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))

# %%
ann_Ca = tf.keras.models.Sequential()
ann_Ca.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_Ca.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Ca.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Ca.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Ca.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Ca.add(tf.keras.layers.Dense(units=1))
ann_Ca.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_Ca= ann_Ca.fit(X_Ca_train, y_Ca_train, validation_split=0.33, batch_size = 16, epochs = 500)


y_pred_Ca_test = ann_Ca.predict(X_Ca_test)

y_pred_Ca_train = ann_Ca.predict(X_Ca_train)


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))

# %%
ann_Cl = tf.keras.models.Sequential()
ann_Cl.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_Cl.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Cl.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Cl.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Cl.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Cl.add(tf.keras.layers.Dense(units=1))
ann_Cl.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_Cl= ann_Cl.fit(X_Cl_train, y_Cl_train, validation_split=0.33, batch_size = 16, epochs = 500)


y_pred_Cl_test = ann_Cl.predict(X_Cl_test)

y_pred_Cl_train = ann_Cl.predict(X_Cl_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))

# %%
ann_K = tf.keras.models.Sequential()
ann_K.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_K.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_K.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_K.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_K.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_K.add(tf.keras.layers.Dense(units=1))
ann_K.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_K= ann_K.fit(X_K_train, y_K_train, validation_split=0.33, batch_size = 16, epochs = 500)


y_pred_K_test = ann_K.predict(X_K_test)

y_pred_K_train = ann_K.predict(X_K_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))

# %%
ann_Mg = tf.keras.models.Sequential()
ann_Mg.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_Mg.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Mg.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Mg.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Mg.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Mg.add(tf.keras.layers.Dense(units=1))
ann_Mg.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_Mg= ann_Mg.fit(X_Mg_train, y_Mg_train, validation_split=0.33, batch_size = 16, epochs = 500)

y_pred_Mg_test = ann_Mg.predict(X_Mg_test)

y_pred_Mg_train = ann_Mg.predict(X_Mg_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))

# %%
ann_Na = tf.keras.models.Sequential()
ann_Na.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_Na.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Na.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_Na.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Na.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_Na.add(tf.keras.layers.Dense(units=1))
ann_Na.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history= ann_Na.fit(X_Na_train, y_Na_train, validation_split=0.33, batch_size = 16, epochs = 500)

y_pred_Na_test = ann_Na.predict(X_Na_test)

y_pred_Na_train = ann_Na.predict(X_Na_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))

# %%
ann_SO4 = tf.keras.models.Sequential()
ann_SO4.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_SO4.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_SO4.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_SO4.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_SO4.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_SO4.add(tf.keras.layers.Dense(units=1))
ann_SO4.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_SO4= ann_SO4.fit(X_SO4_train, y_SO4_train, validation_split=0.33, batch_size = 16, epochs = 500)

y_pred_SO4_test = ann_SO4.predict(X_SO4_test)

y_pred_SO4_train = ann_SO4.predict(X_SO4_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))

# %%
ann_TDS = tf.keras.models.Sequential()
ann_TDS.add(tf.keras.layers.Dense(units=7, activation='ELU'))
ann_TDS.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_TDS.add(tf.keras.layers.Dense(units=10, activation='ELU'))
ann_TDS.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_TDS.add(tf.keras.layers.Dense(units=5, activation='ELU'))
ann_TDS.add(tf.keras.layers.Dense(units=1))
ann_TDS.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001), loss="mse",metrics=['accuracy'])
history_TDS= ann_TDS.fit(X_TDS_train, y_TDS_train, validation_split=0.33, batch_size = 16, epochs = 500)

y_pred_TDS_test = ann_TDS.predict(X_TDS_test)

y_pred_TDS_train = ann_TDS.predict(X_TDS_train)

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print("Alkalinity: ","Training","R2 =",round(r2_score(y_alk_train,y_pred_alk_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_alk_train,y_pred_alk_train),ndigits=2), "  MSE =", round(mean_squared_error(y_alk_train, y_pred_alk_train),ndigits=2))
print("Alkalinity: ","Test    ","R2 =",round(r2_score(y_alk_test,y_pred_alk_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_alk_test, y_pred_alk_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_alk_test, y_pred_alk_test),ndigits=2))
print("  ")
print("Br: ","Training","R2 =",round(r2_score(y_Br_train,y_pred_Br_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Br_train,y_pred_Br_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Br_train, y_pred_Br_train),ndigits=2))
print("Br: ","Test    ","R2 =",round(r2_score(y_Br_test,y_pred_Br_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Br_test, y_pred_Br_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Br_test, y_pred_Br_test),ndigits=2))
print("  ")
print("Ca: ","Training","R2 =",round(r2_score(y_Ca_train,y_pred_Ca_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Ca_train,y_pred_Ca_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Ca_train, y_pred_Ca_train),ndigits=2))
print("Ca: ","Test    ","R2 =",round(r2_score(y_Ca_test,y_pred_Ca_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Ca_test, y_pred_Ca_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Ca_test, y_pred_Ca_test),ndigits=2))
print("  ")
print("Cl: ","Training","R2 =",round(r2_score(y_Cl_train,y_pred_Cl_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Cl_train,y_pred_Cl_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Cl_train, y_pred_Cl_train),ndigits=2))
print("Cl: ","Test    ","R2 =",round(r2_score(y_Cl_test,y_pred_Cl_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Cl_test, y_pred_Cl_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Cl_test, y_pred_Cl_test),ndigits=2))
print("  ")
print("K: ","Training","R2 =",round(r2_score(y_K_train,y_pred_K_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_K_train,y_pred_K_train),ndigits=2), "  MSE =", round(mean_squared_error(y_K_train, y_pred_K_train),ndigits=2))
print("K: ","Test    ","R2 =",round(r2_score(y_K_test,y_pred_K_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_K_test, y_pred_K_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_K_test, y_pred_K_test),ndigits=2))
print("  ")
print("Mg: ","Training","R2 =",round(r2_score(y_Mg_train,y_pred_Mg_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Mg_train,y_pred_Mg_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Mg_train, y_pred_Mg_train),ndigits=2))
print("Mg: ","Test    ","R2 =",round(r2_score(y_Mg_test,y_pred_Mg_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Mg_test, y_pred_Mg_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Mg_test, y_pred_Mg_test),ndigits=2))
print("  ")
print("Na: ","Training","R2 =",round(r2_score(y_Na_train,y_pred_Na_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_Na_train,y_pred_Na_train),ndigits=2), "  MSE =", round(mean_squared_error(y_Na_train, y_pred_Na_train),ndigits=2))
print("Na: ","Test    ","R2 =",round(r2_score(y_Na_test,y_pred_Na_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_Na_test, y_pred_Na_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_Na_test, y_pred_Na_test),ndigits=2))
print("  ")
print("SO4: ","Training","R2 =",round(r2_score(y_SO4_train,y_pred_SO4_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_SO4_train,y_pred_SO4_train),ndigits=2), "  MSE =", round(mean_squared_error(y_SO4_train, y_pred_SO4_train),ndigits=2))
print("SO4: ","Test    ","R2 =",round(r2_score(y_SO4_test,y_pred_SO4_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_SO4_test, y_pred_SO4_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_SO4_test, y_pred_SO4_test),ndigits=2))
print("  ")
print("TDS: ","Training","R2 =",round(r2_score(y_TDS_train,y_pred_TDS_train),ndigits=2),"  MAE =", round(mean_absolute_error(y_TDS_train,y_pred_TDS_train),ndigits=2), "  MSE =", round(mean_squared_error(y_TDS_train, y_pred_TDS_train),ndigits=2))
print("TDS: ","Test    ","R2 =",round(r2_score(y_TDS_test,y_pred_TDS_test),ndigits=2),  "  MAE =" , round(mean_absolute_error(y_TDS_test, y_pred_TDS_test),ndigits=2),  "  MSE =", round(mean_squared_error(y_TDS_test, y_pred_TDS_test),ndigits=2))

# %%
fig, axes=plt.subplots(3,3,figsize=(20,15),dpi=200)


axes[0,0].scatter(y_pred_TDS_test, y_TDS_test, color = 'red')
axes[0,0].plot((0,800),(0,800) ,'b--', label="Perfect model line (1:1)")
axes[0,0].set_xlabel('Observed')
axes[0,0].set_ylabel('Simulated')
axes[0,0].set_title('TDS_Test dataset')
axes[0,0].legend(loc=0)


axes[0,1].scatter(y_pred_SO4_test, y_SO4_test, color = 'red')
axes[0,1].plot((0,160),(0,160) ,'b--', label="Perfect model line (1:1)")
axes[0,1].set_xlabel('Observed')
axes[0,1].set_ylabel('Simulated')
axes[0,1].set_title('SO4_Test dataset')
axes[0,1].legend(loc=0)

axes[0,2].scatter(y_pred_Na_test, y_Na_test, color = 'red')
axes[0,2].plot((0,190),(0,190) ,'b--', label="Perfect model line (1:1)")
axes[0,2].set_xlabel('Observed')
axes[0,2].set_ylabel('Simulated')
axes[0,2].set_title('Na_Test dataset')
axes[0,2].legend(loc=0)

axes[1,0].scatter(y_pred_Mg_test, y_Mg_test, color = 'red')
axes[1,0].plot((0,40),(0,40) ,'b--', label="Perfect model line (1:1)")
axes[1,0].set_xlabel('Observed')
axes[1,0].set_ylabel('Simulated')
axes[1,0].set_title('Mg_Test dataset')
axes[1,0].legend(loc=0)

axes[1,1].scatter(y_pred_K_test, y_K_test, color = 'red')
axes[1,1].plot((0,12),(0,12) ,'b--', label="Perfect model line (1:1)")
axes[1,1].set_xlabel('Observed')
axes[1,1].set_ylabel('Simulated')
axes[1,1].set_title('K_Test dataset')
axes[1,1].legend(loc=0)

axes[1,2].scatter(y_pred_Cl_test, y_Cl_test, color = 'red')
axes[1,2].plot((0,600),(0,600) ,'b--', label="Perfect model line (1:1)")
axes[1,2].set_xlabel('Observed')
axes[1,2].set_ylabel('Simulated')
axes[1,2].set_title('Cl_Test dataset')
axes[1,2].legend(loc=0)

axes[2,0].scatter(y_pred_Ca_test, y_Ca_test, color = 'red')
axes[2,0].plot((0,80),(0,80) ,'b--', label="Perfect model line (1:1)")
axes[2,0].set_xlabel('Observed')
axes[2,0].set_ylabel('Simulated')
axes[2,0].set_title('Ca_Test dataset')
axes[2,0].legend(loc=0)

axes[2,1].scatter(y_pred_Br_test, y_Br_test, color = 'red')
axes[2,1].plot((0,1),(0,1) ,'b--', label="Perfect model line (1:1)")
axes[2,1].set_xlabel('Observed')
axes[2,1].set_ylabel('Simulated')
axes[2,1].set_title('Br_Test dataset')
axes[2,1].legend(loc=0)

axes[2,2].scatter(y_pred_alk_test, y_alk_test, color = 'red')
axes[2,2].plot((0,250),(0,250) ,'b--', label="Perfect model line (1:1)")
axes[2,2].set_xlabel('Observed')
axes[2,2].set_ylabel('Simulated')
axes[2,2].set_title('Alkalinity_Test dataset')
axes[2,2].legend(loc=0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import seaborn as sns

# %%
Alk_path="inputs/Alkalinity.csv"
Br_path="inputs/Br.csv"
Ca_path="inputs/Ca.csv"
Cl_path="inputs/Cl.csv"
K_path="inputs/K.csv"
Mg_path="inputs/Mg.csv"
Na_path="inputs/Na.csv"
SO4_path="inputs/SO4.csv"
TDS_path="inputs/TDS.csv"

Alkalinity= pd.read_csv(Alk_path)
Br= pd.read_csv(Br_path)
Ca= pd.read_csv(Ca_path)
Cl= pd.read_csv(Cl_path)
K= pd.read_csv(K_path)
Mg= pd.read_csv(Mg_path)
Na= pd.read_csv(Na_path)
SO4= pd.read_csv(SO4_path)
TDS= pd.read_csv(TDS_path)

Alkalinity= pd.DataFrame(Alkalinity)
Br= pd.DataFrame(Br)
Ca= pd.DataFrame(Ca)
Cl= pd.DataFrame(Cl)
K = pd.DataFrame(K)
Mg= pd.DataFrame(Mg)
Na= pd.DataFrame(Na)
SO4= pd.DataFrame(SO4)
TDS= pd.DataFrame(TDS)

# %%
Alkalinity.head()

# %%
dataset2=Alkalinity['Collection Date'].str.split("/",n=2, expand=True)
dataset2 = pd.DataFrame(dataset2)
Alkalinity['year'] = dataset2[2].astype('int')
Alkalinity['Month'] = dataset2[0].astype('int')

dataset3=Br['Collection Date'].str.split("/",n=2, expand=True)
dataset3 = pd.DataFrame(dataset3)
Br['year'] = dataset3[2].astype('int')
Br['Month'] = dataset3[0].astype('int')

dataset4=Ca['Collection Date'].str.split("/",n=2, expand=True)
dataset4 = pd.DataFrame(dataset4)
Ca['year'] = dataset4[2].astype('int')
Ca['Month'] = dataset4[0].astype('int')

dataset5=Cl['Collection Date'].str.split("/",n=2, expand=True)
dataset5 = pd.DataFrame(dataset5)
Cl['year'] = dataset5[2].astype('int')
Cl['Month'] = dataset5[0].astype('int')

dataset6=Ca['Collection Date'].str.split("/",n=2, expand=True)
dataset6 = pd.DataFrame(dataset6)
Ca['year'] = dataset6[2].astype('int')
Ca['Month'] = dataset6[0].astype('int')

dataset7=K['Collection Date'].str.split("/",n=2, expand=True)
dataset7 = pd.DataFrame(dataset7)
K['year'] = dataset7[2].astype('int')
K['Month'] = dataset7[0].astype('int')

dataset8=Mg['Collection Date'].str.split("/",n=2, expand=True)
dataset8 = pd.DataFrame(dataset8)
Mg['year'] = dataset8[2].astype('int')
Mg['Month'] = dataset8[0].astype('int')

dataset9=Na['Collection Date'].str.split("/",n=2, expand=True)
dataset9 = pd.DataFrame(dataset9)
Na['year'] = dataset9[2].astype('int')
Na['Month'] = dataset9[0].astype('int')

dataset10=SO4['Collection Date'].str.split("/",n=2, expand=True)
dataset10 = pd.DataFrame(dataset10)
SO4['year'] = dataset10[2].astype('int')
SO4['Month'] = dataset10[0].astype('int')

dataset11=TDS['Collection Date'].str.split("/",n=2, expand=True)
dataset11 = pd.DataFrame(dataset11)
TDS['year'] = dataset11[2].astype('int')
TDS['Month'] = dataset11[0].astype('int')

# %%
TDS.head()

# %%
Alkalinity['Location'].unique()

# %%
Alkalinity['WYT'].unique()

# %%
alk_south=Alkalinity[Alkalinity['Location'].isin(['SouthDelta'])]
alk_south=pd.DataFrame(alk_south)

Br_south=Br[Br['Location'].isin(['SouthDelta'])]
Br_south=pd.DataFrame(Br_south)

Ca_south=Ca[Ca['Location'].isin(['SouthDelta'])]
Ca_south=pd.DataFrame(Ca_south)

Cl_south=Cl[Cl['Location'].isin(['SouthDelta'])]
Cl_south=pd.DataFrame(Cl_south)

K_south=K[K['Location'].isin(['SouthDelta'])]
K_south=pd.DataFrame(K_south)

Mg_south=Mg[Mg['Location'].isin(['SouthDelta'])]
Mg_south=pd.DataFrame(Mg_south)

Na_south=Na[Na['Location'].isin(['SouthDelta'])]
Na_south=pd.DataFrame(Na_south)

SO4_south=SO4[SO4['Location'].isin(['SouthDelta'])]
SO4_south=pd.DataFrame(SO4_south)

TDS_south=TDS[TDS['Location'].isin(['SouthDelta'])]
TDS_south=pd.DataFrame(TDS_south)

# %%
alk_SJ=Alkalinity[Alkalinity['Location'].isin(['SJRcorridor'])]
alk_SJ=pd.DataFrame(alk_SJ)

Br_SJ=Br[Br['Location'].isin(['SJRcorridor'])]
Br_SJ=pd.DataFrame(Br_SJ)

Ca_SJ=Ca[Ca['Location'].isin(['SJRcorridor'])]
Ca_SJ=pd.DataFrame(Ca_SJ)

Cl_SJ=Cl[Cl['Location'].isin(['SJRcorridor'])]
Cl_SJ=pd.DataFrame(Cl_SJ)

K_SJ=K[K['Location'].isin(['SJRcorridor'])]
K_SJ=pd.DataFrame(K_SJ)

Mg_SJ=Mg[Mg['Location'].isin(['SJRcorridor'])]
Mg_SJ=pd.DataFrame(Mg_SJ)

Na_SJ=Na[Na['Location'].isin(['SJRcorridor'])]
Na_SJ=pd.DataFrame(Na_SJ)

SO4_SJ=SO4[SO4['Location'].isin(['SJRcorridor'])]
SO4_SJ=pd.DataFrame(SO4_SJ)

TDS_SJ=TDS[TDS['Location'].isin(['SJRcorridor'])]
TDS_SJ=pd.DataFrame(TDS_SJ)

# %%
alk_OMR=Alkalinity[Alkalinity['Location'].isin(['OMR'])]
alk_OMR=pd.DataFrame(alk_OMR)

Br_OMR=Br[Br['Location'].isin(['OMR'])]
Br_OMR=pd.DataFrame(Br_OMR)

Ca_OMR=Ca[Ca['Location'].isin(['OMR'])]
Ca_OMR=pd.DataFrame(Ca_OMR)

Cl_OMR=Cl[Cl['Location'].isin(['OMR'])]
Cl_OMR=pd.DataFrame(Cl_OMR)

K_OMR=K[K['Location'].isin(['OMR'])]
K_OMR=pd.DataFrame(K_OMR)

Mg_OMR=Mg[Mg['Location'].isin(['OMR'])]
Mg_OMR=pd.DataFrame(Mg_OMR)

Na_OMR=Na[Na['Location'].isin(['OMR'])]
Na_OMR=pd.DataFrame(Na_OMR)

SO4_OMR=SO4[SO4['Location'].isin(['OMR'])]
SO4_OMR=pd.DataFrame(SO4_OMR)

TDS_OMR=TDS[TDS['Location'].isin(['OMR'])]
TDS_OMR=pd.DataFrame(TDS_OMR)

# %%
print('TDS',TDS_south.shape)
print('Br',Br_south.shape)
print('Cl',Cl_south.shape)
print('SO4',SO4_south.shape)
print('Alkalinity', alk_south.shape)
print('Na',Na_south.shape)
print('Ca',Ca_south.shape)
print('Mg',Mg_south.shape)
print('K',K_south.shape)

# %%
print('TDS',TDS_SJ.shape)
print('Br',Br_SJ.shape)
print('Cl',Cl_SJ.shape)
print('SO4',SO4_SJ.shape)
print('Alkalinity', alk_SJ.shape)
print('Na',Na_SJ.shape)
print('Ca',Ca_SJ.shape)
print('Mg',Mg_SJ.shape)
print('K',K_SJ.shape)

# %%
print('TDS',TDS_OMR.shape)
print('Br',Br_OMR.shape)
print('Cl',Cl_OMR.shape)
print('SO4',SO4_OMR.shape)
print('Alkalinity', alk_OMR.shape)
print('Na',Na_OMR.shape)
print('Ca',Ca_OMR.shape)
print('Mg',Mg_OMR.shape)
print('K',K_OMR.shape)

# %%
alk_SJ.head()

# %%
alk_south.head()

# %%
alk_OMR.head()

# %%
alk_south['simulated'] = np.nan
Br_south['simulated'] = np.nan
Ca_south['simulated'] = np.nan
Cl_south['simulated'] = np.nan
K_south['simulated'] = np.nan
Mg_south['simulated'] = np.nan
Na_south['simulated'] = np.nan
SO4_south['simulated'] = np.nan
TDS_south['simulated'] = np.nan

# %%
alk_SJ['simulated'] = np.nan
Br_SJ['simulated'] = np.nan
Ca_SJ['simulated'] = np.nan
Cl_SJ['simulated'] = np.nan
K_SJ['simulated'] = np.nan
Mg_SJ['simulated'] = np.nan
Na_SJ['simulated'] = np.nan
SO4_SJ['simulated'] = np.nan
TDS_SJ['simulated'] = np.nan

# %%
alk_OMR['simulated'] = np.nan
Br_OMR['simulated'] = np.nan
Ca_OMR['simulated'] = np.nan
Cl_OMR['simulated'] = np.nan
K_OMR['simulated'] = np.nan
Mg_OMR['simulated'] = np.nan
Na_OMR['simulated'] = np.nan
SO4_OMR['simulated'] = np.nan
TDS_OMR['simulated'] = np.nan

# %%
alk_south.head()

# %%
alk_SJ.head()

# %%
####################### South Delta Unknown X2 #########################

alk_south.loc[(alk_south['WYT'] == 'BN') & ((alk_south['Month']<3) | (alk_south['Month']>7)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1
alk_south.loc[(alk_south['WYT'] == 'D') & ((alk_south['Month']<3) | (alk_south['Month']>7)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1
alk_south.loc[(alk_south['WYT'] == 'C') & ((alk_south['Month']<3) | (alk_south['Month']>5)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1
alk_south.loc[(alk_south['WYT'] == 'AN') & ((alk_south['Month']<2) | (alk_south['Month']>8)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1

Br_south.loc[(Br_south['WYT'] == 'BN') & ((Br_south['Month']<3) | (Br_south['Month']>7)), 'simulated'] = -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12
Br_south.loc[(Br_south['WYT'] == 'D') & ((Br_south['Month']<3) | (Br_south['Month']>7)), 'simulated'] =  -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12
Br_south.loc[(Br_south['WYT'] == 'C') & ((Br_south['Month']<3) | (Br_south['Month']>5)), 'simulated'] =  -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12
Br_south.loc[(Br_south['WYT'] == 'AN') & ((Br_south['Month']<2) | (Br_south['Month']>8)), 'simulated'] = -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12

Ca_south.loc[(Ca_south['WYT'] == 'BN') & ((Ca_south['Month']<3) | (Ca_south['Month']>7)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3
Ca_south.loc[(Ca_south['WYT'] == 'D') & ((Ca_south['Month']<3) | (Ca_south['Month']>7)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3
Ca_south.loc[(Ca_south['WYT'] == 'C') & ((Ca_south['Month']<3) | (Ca_south['Month']>5)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3
Ca_south.loc[(Ca_south['WYT'] == 'AN') & ((Ca_south['Month']<2) | (Ca_south['Month']>8)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3

Cl_south.loc[(Cl_south['WYT'] == 'BN') & ((Cl_south['Month']<3) | (Cl_south['Month']>7)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3
Cl_south.loc[(Cl_south['WYT'] == 'D') & ((Cl_south['Month']<3) | (Cl_south['Month']>7)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3
Cl_south.loc[(Cl_south['WYT'] == 'C') & ((Cl_south['Month']<3) | (Cl_south['Month']>5)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3
Cl_south.loc[(Cl_south['WYT'] == 'AN') & ((Cl_south['Month']<2) | (Cl_south['Month']>8)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3

K_south.loc[(K_south['WYT'] == 'BN') & ((K_south['Month']<3) | (K_south['Month']>7)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4
K_south.loc[(K_south['WYT'] == 'D') & ((K_south['Month']<3) | (K_south['Month']>7)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4
K_south.loc[(K_south['WYT'] == 'C') & ((K_south['Month']<3) | (K_south['Month']>5)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4
K_south.loc[(K_south['WYT'] == 'AN') & ((K_south['Month']<2) | (K_south['Month']>8)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4

Mg_south.loc[(Mg_south['WYT'] == 'BN') & ((Mg_south['Month']<3) | (Mg_south['Month']>7)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6
Mg_south.loc[(Mg_south['WYT'] == 'D') & ((Mg_south['Month']<3) | (Mg_south['Month']>7)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6
Mg_south.loc[(Mg_south['WYT'] == 'C') & ((Mg_south['Month']<3) | (Mg_south['Month']>5)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6
Mg_south.loc[(Mg_south['WYT'] == 'AN') & ((Mg_south['Month']<2) | (Mg_south['Month']>8)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6

Na_south.loc[(Na_south['WYT'] == 'BN') & ((Na_south['Month']<3) | (Na_south['Month']>7)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5
Na_south.loc[(Na_south['WYT'] == 'D') & ((Na_south['Month']<3) | (Na_south['Month']>7)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5
Na_south.loc[(Na_south['WYT'] == 'C') & ((Na_south['Month']<3) | (Na_south['Month']>5)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5
Na_south.loc[(Na_south['WYT'] == 'AN') & ((Na_south['Month']<2) | (Na_south['Month']>8)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5

SO4_south.loc[(SO4_south['WYT'] == 'BN') & ((SO4_south['Month']<3) | (SO4_south['Month']>7)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1
SO4_south.loc[(SO4_south['WYT'] == 'D') & ((SO4_south['Month']<3) | (SO4_south['Month']>7)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1
SO4_south.loc[(SO4_south['WYT'] == 'C') & ((SO4_south['Month']<3) | (SO4_south['Month']>5)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1
SO4_south.loc[(SO4_south['WYT'] == 'AN') & ((SO4_south['Month']<2) | (SO4_south['Month']>8)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1

TDS_south.loc[(TDS_south['WYT'] == 'BN') & ((TDS_south['Month']<3) | (TDS_south['Month']>7)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8
TDS_south.loc[(TDS_south['WYT'] == 'D') & ((TDS_south['Month']<3) | (TDS_south['Month']>7)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8
TDS_south.loc[(TDS_south['WYT'] == 'C') & ((TDS_south['Month']<3) | (TDS_south['Month']>5)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8
TDS_south.loc[(TDS_south['WYT'] == 'AN') & ((TDS_south['Month']<2) | (TDS_south['Month']>8)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8

alk_south.loc[(alk_south['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.162*(alk_south['EC'])+9.5

Br_south.loc[(Br_south['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_south['EC'])*(Br_south['EC'])+ 0.000458*(Br_south['EC']) -0.05

Ca_south.loc[(Ca_south['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0420*(Ca_south['EC'])+ 3.4

Cl_south.loc[(Cl_south['simulated'].isnull()), 'simulated'] = 6.50E-06*(Cl_south['EC'])*(Cl_south['EC'])+ 0.147*(Cl_south['EC']) - 12.5

K_south.loc[(K_south['simulated'].isnull()), 'simulated'] =3.78E-07*(K_south['EC'])*(K_south['EC'])+ 0.00232*(K_south['EC'])+ 1.0

Mg_south.loc[(Mg_south['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0232*(Mg_south['EC'])+ 0.5

Na_south.loc[(Na_south['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_south['EC'])*(Na_south['EC'])+ 0.110*(Na_south['EC']) -3.9

SO4_south.loc[(SO4_south['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_south['EC'])*(SO4_south['EC'])+ 0.0917*(SO4_south['EC'])+ 3.8

TDS_south.loc[(TDS_south['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.526*(TDS_south['EC'])+ 11.3

# %%
####################### South Delta known X2 #########################

alk_south.loc[(alk_south['WYT'] == 'BN') & ((alk_south['Month']<3) | (alk_south['Month']>7)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1
alk_south.loc[(alk_south['WYT'] == 'D') & ((alk_south['Month']<3) | (alk_south['Month']>7)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1
alk_south.loc[(alk_south['WYT'] == 'C') & ((alk_south['Month']<3) | (alk_south['Month']>5)), 'simulated'] = 2.91E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.0545*(alk_south['EC'])+41.1

Br_south.loc[(Br_south['WYT'] == 'BN') & ((Br_south['Month']<3) | (Br_south['Month']>7)), 'simulated'] = -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12
Br_south.loc[(Br_south['WYT'] == 'D') & ((Br_south['Month']<3) | (Br_south['Month']>7)), 'simulated'] =  -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12
Br_south.loc[(Br_south['WYT'] == 'C') & ((Br_south['Month']<3) | (Br_south['Month']>5)), 'simulated'] =  -3.31E-07*(Br_south['EC'])*(Br_south['EC'])+ 0.000963*(Br_south['EC']) - 0.12

Ca_south.loc[(Ca_south['WYT'] == 'BN') & ((Ca_south['Month']<3) | (Ca_south['Month']>7)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3
Ca_south.loc[(Ca_south['WYT'] == 'D') & ((Ca_south['Month']<3) | (Ca_south['Month']>7)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3
Ca_south.loc[(Ca_south['WYT'] == 'C') & ((Ca_south['Month']<3) | (Ca_south['Month']>5)), 'simulated'] = 2.66E-05*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0107*(Ca_south['EC'])+8.3

Cl_south.loc[(Cl_south['WYT'] == 'BN') & ((Cl_south['Month']<3) | (Cl_south['Month']>7)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3
Cl_south.loc[(Cl_south['WYT'] == 'D') & ((Cl_south['Month']<3) | (Cl_south['Month']>7)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3
Cl_south.loc[(Cl_south['WYT'] == 'C') & ((Cl_south['Month']<3) | (Cl_south['Month']>5)), 'simulated'] = -6.56E-05*(Cl_south['EC'])*(Cl_south['EC'])+ 0.259*(Cl_south['EC'])-30.3

K_south.loc[(K_south['WYT'] == 'BN') & ((K_south['Month']<3) | (K_south['Month']>7)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4
K_south.loc[(K_south['WYT'] == 'D') & ((K_south['Month']<3) | (K_south['Month']>7)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4
K_south.loc[(K_south['WYT'] == 'C') & ((K_south['Month']<3) | (K_south['Month']>5)), 'simulated'] = -3.01E-06*(K_south['EC'])*(K_south['EC'])+ 0.00708*(K_south['EC'])+0.4

Mg_south.loc[(Mg_south['WYT'] == 'BN') & ((Mg_south['Month']<3) | (Mg_south['Month']>7)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6
Mg_south.loc[(Mg_south['WYT'] == 'D') & ((Mg_south['Month']<3) | (Mg_south['Month']>7)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6
Mg_south.loc[(Mg_south['WYT'] == 'C') & ((Mg_south['Month']<3) | (Mg_south['Month']>5)), 'simulated'] = 3.73E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0203*(Mg_south['EC'])+2.6

Na_south.loc[(Na_south['WYT'] == 'BN') & ((Na_south['Month']<3) | (Na_south['Month']>7)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5
Na_south.loc[(Na_south['WYT'] == 'D') & ((Na_south['Month']<3) | (Na_south['Month']>7)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5
Na_south.loc[(Na_south['WYT'] == 'C') & ((Na_south['Month']<3) | (Na_south['Month']>5)), 'simulated'] = -8.52E-06*(Na_south['EC'])*(Na_south['EC'])+ 0.136*(Na_south['EC']) - 10.5

SO4_south.loc[(SO4_south['WYT'] == 'BN') & ((SO4_south['Month']<3) | (SO4_south['Month']>7)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1
SO4_south.loc[(SO4_south['WYT'] == 'D') & ((SO4_south['Month']<3) | (SO4_south['Month']>7)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1
SO4_south.loc[(SO4_south['WYT'] == 'C') & ((SO4_south['Month']<3) | (SO4_south['Month']>5)), 'simulated'] = 1.15E-04*(SO4_south['EC'])*(SO4_south['EC'])+ 0.00158*(SO4_south['EC'])+5.1

TDS_south.loc[(TDS_south['WYT'] == 'BN') & ((TDS_south['Month']<3) | (TDS_south['Month']>7)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8
TDS_south.loc[(TDS_south['WYT'] == 'D') & ((TDS_south['Month']<3) | (TDS_south['Month']>7)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8
TDS_south.loc[(TDS_south['WYT'] == 'C') & ((TDS_south['Month']<3) | (TDS_south['Month']>5)), 'simulated'] = 6.32E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.500*(TDS_south['EC'])+13.8

alk_south.loc[(alk_south['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_south['EC'])*(alk_south['EC'])+ 0.162*(alk_south['EC'])+9.5

Br_south.loc[(Br_south['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_south['EC'])*(Br_south['EC'])+ 0.000458*(Br_south['EC']) -0.05

Ca_south.loc[(Ca_south['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_south['EC'])*(Ca_south['EC'])+ 0.0420*(Ca_south['EC'])+ 3.4

Cl_south.loc[(Cl_south['simulated'].isnull()), 'simulated'] = 6.50E-06*(Cl_south['EC'])*(Cl_south['EC'])+ 0.147*(Cl_south['EC']) - 12.5

K_south.loc[(K_south['simulated'].isnull()), 'simulated'] =3.78E-07*(K_south['EC'])*(K_south['EC'])+ 0.00232*(K_south['EC'])+ 1.0

Mg_south.loc[(Mg_south['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_south['EC'])*(Mg_south['EC'])+ 0.0232*(Mg_south['EC'])+ 0.5

Na_south.loc[(Na_south['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_south['EC'])*(Na_south['EC'])+ 0.110*(Na_south['EC']) -3.9

SO4_south.loc[(SO4_south['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_south['EC'])*(SO4_south['EC'])+ 0.0917*(SO4_south['EC'])+ 3.8

TDS_south.loc[(TDS_south['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_south['EC'])*(TDS_south['EC'])+ 0.526*(TDS_south['EC'])+ 11.3

# %% [markdown]
#  SJ calculations

# %%
##################San Joaquin River Corridor Subregion#######################
###################X2 position is unknown########################################


alk_SJ.loc[(alk_SJ['WYT'] == 'D') & (alk_SJ['Month']>7), 'simulated'] = 2.91E-05*(alk_SJ['EC'])*(alk_SJ['EC'])+ 0.0545*(alk_SJ['EC'])+41.1
alk_SJ.loc[(alk_SJ['WYT'] == 'C') & (alk_SJ['Month']>5), 'simulated'] = 2.91E-05*(alk_SJ['EC'])*(alk_SJ['EC'])+ 0.0545*(alk_SJ['EC'])+41.1

Br_SJ.loc[(Br_SJ['WYT'] == 'D') & (Br_SJ['Month']>7), 'simulated'] =  -3.31E-07*(Br_SJ['EC'])*(Br_SJ['EC'])+ 0.000963*(Br_SJ['EC']) - 0.12
Br_SJ.loc[(Br_SJ['WYT'] == 'C') & (Br_SJ['Month']>5), 'simulated'] =  -3.31E-07*(Br_SJ['EC'])*(Br_SJ['EC'])+ 0.000963*(Br_SJ['EC']) - 0.12

Ca_SJ.loc[(Ca_SJ['WYT'] == 'D') & (Ca_SJ['Month']>7), 'simulated'] = 2.66E-05*(Ca_SJ['EC'])*(Ca_SJ['EC'])+ 0.0107*(Ca_SJ['EC'])+8.3
Ca_SJ.loc[(Ca_SJ['WYT'] == 'C') & (Ca_SJ['Month']>5), 'simulated'] = 2.66E-05*(Ca_SJ['EC'])*(Ca_SJ['EC'])+ 0.0107*(Ca_SJ['EC'])+8.3

Cl_SJ.loc[(Cl_SJ['WYT'] == 'D') & (Cl_SJ['Month']>7), 'simulated'] = -6.56E-05*(Cl_SJ['EC'])*(Cl_SJ['EC'])+ 0.259*(Cl_SJ['EC'])-30.3
Cl_SJ.loc[(Cl_SJ['WYT'] == 'C') & (Cl_SJ['Month']>5), 'simulated'] = -6.56E-05*(Cl_SJ['EC'])*(Cl_SJ['EC'])+ 0.259*(Cl_SJ['EC'])-30.3

K_SJ.loc[(K_SJ['WYT'] == 'D') & (K_SJ['Month']>7), 'simulated'] = -3.01E-06*(K_SJ['EC'])*(K_SJ['EC'])+ 0.00708*(K_SJ['EC'])+0.4
K_SJ.loc[(K_SJ['WYT'] == 'C') & (K_SJ['Month']>5), 'simulated'] = -3.01E-06*(K_SJ['EC'])*(K_SJ['EC'])+ 0.00708*(K_SJ['EC'])+0.4

Mg_SJ.loc[(Mg_SJ['WYT'] == 'D') & (Mg_SJ['Month']>7), 'simulated'] = 3.73E-06*(Mg_SJ['EC'])*(Mg_SJ['EC'])+ 0.0203*(Mg_SJ['EC'])+2.6
Mg_SJ.loc[(Mg_SJ['WYT'] == 'C') & (Mg_SJ['Month']>5), 'simulated'] = 3.73E-06*(Mg_SJ['EC'])*(Mg_SJ['EC'])+ 0.0203*(Mg_SJ['EC'])+2.6

Na_SJ.loc[(Na_SJ['WYT'] == 'D') & (Na_SJ['Month']>7), 'simulated'] = -8.52E-06*(Na_SJ['EC'])*(Na_SJ['EC'])+ 0.136*(Na_SJ['EC']) - 10.5
Na_SJ.loc[(Na_SJ['WYT'] == 'C') & (Na_SJ['Month']>5), 'simulated'] = -8.52E-06*(Na_SJ['EC'])*(Na_SJ['EC'])+ 0.136*(Na_SJ['EC']) - 10.5

SO4_SJ.loc[(SO4_SJ['WYT'] == 'D') & (SO4_SJ['Month']>7), 'simulated'] = 1.15E-04*(SO4_SJ['EC'])*(SO4_SJ['EC'])+ 0.00158*(SO4_SJ['EC'])+5.1
SO4_SJ.loc[(SO4_SJ['WYT'] == 'C') & (SO4_SJ['Month']>5), 'simulated'] = 1.15E-04*(SO4_SJ['EC'])*(SO4_SJ['EC'])+ 0.00158*(SO4_SJ['EC'])+5.1

TDS_SJ.loc[(TDS_SJ['WYT'] == 'D') & (TDS_SJ['Month']>7), 'simulated'] = 6.32E-05*(TDS_SJ['EC'])*(TDS_SJ['EC'])+ 0.500*(TDS_SJ['EC'])+13.8
TDS_SJ.loc[(TDS_SJ['WYT'] == 'C') & (TDS_SJ['Month']>5), 'simulated'] = 6.32E-05*(TDS_SJ['EC'])*(TDS_SJ['EC'])+ 0.500*(TDS_SJ['EC'])+13.8


alk_SJ.loc[(alk_SJ['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_SJ['EC'])*(alk_SJ['EC'])+ 0.162*(alk_SJ['EC'])+9.5

Br_SJ.loc[(Br_SJ['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_SJ['EC'])*(Br_SJ['EC'])+ 0.000458*(Br_SJ['EC']) -0.05

Ca_SJ.loc[(Ca_SJ['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_SJ['EC'])*(Ca_SJ['EC'])+ 0.0420*(Ca_SJ['EC'])+ 3.4

Cl_SJ.loc[(Cl_SJ['simulated'].isnull()), 'simulated'] = 6.50E-06*(Cl_SJ['EC'])*(Cl_SJ['EC'])+ 0.147*(Cl_SJ['EC']) - 12.5

K_SJ.loc[(K_SJ['simulated'].isnull()), 'simulated'] =3.78E-07*(K_SJ['EC'])*(K_SJ['EC'])+ 0.00232*(K_SJ['EC'])+ 1.0

Mg_SJ.loc[(Mg_SJ['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_SJ['EC'])*(Mg_SJ['EC'])+ 0.0232*(Mg_SJ['EC'])+ 0.5

Na_SJ.loc[(Na_SJ['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_SJ['EC'])*(Na_SJ['EC'])+ 0.110*(Na_SJ['EC']) -3.9

SO4_SJ.loc[(SO4_SJ['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_SJ['EC'])*(SO4_SJ['EC'])+ 0.0917*(SO4_SJ['EC'])+ 3.8

TDS_SJ.loc[(TDS_SJ['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_SJ['EC'])*(TDS_SJ['EC'])+ 0.526*(TDS_SJ['EC'])+ 11.3

# %%
##################San Joaquin River Corridor Subregion#######################
###################X2 position is known########################################

alk_SJ.loc[(alk_SJ['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_SJ['EC'])*(alk_SJ['EC'])+ 0.162*(alk_SJ['EC'])+9.5

Br_SJ.loc[(Br_SJ['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_SJ['EC'])*(Br_SJ['EC'])+ 0.000458*(Br_SJ['EC']) -0.05

Ca_SJ.loc[(Ca_SJ['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_SJ['EC'])*(Ca_SJ['EC'])+ 0.0420*(Ca_SJ['EC'])+ 3.4

Cl_SJ.loc[(Cl_SJ['simulated'].isnull()), 'simulated'] = 6.50E-06*(Cl_SJ['EC'])*(Cl_SJ['EC'])+ 0.147*(Cl_SJ['EC']) - 12.5

K_SJ.loc[(K_SJ['simulated'].isnull()), 'simulated'] =3.78E-07*(K_SJ['EC'])*(K_SJ['EC'])+ 0.00232*(K_SJ['EC'])+ 1.0

Mg_SJ.loc[(Mg_SJ['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_SJ['EC'])*(Mg_SJ['EC'])+ 0.0232*(Mg_SJ['EC'])+ 0.5

Na_SJ.loc[(Na_SJ['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_SJ['EC'])*(Na_SJ['EC'])+ 0.110*(Na_SJ['EC']) -3.9

SO4_SJ.loc[(SO4_SJ['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_SJ['EC'])*(SO4_SJ['EC'])+ 0.0917*(SO4_SJ['EC'])+ 3.8

TDS_SJ.loc[(TDS_SJ['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_SJ['EC'])*(TDS_SJ['EC'])+ 0.526*(TDS_SJ['EC'])+ 11.3

# %%
##################Old-Middle River Export Corridor Subregion#######################
###################X2 position is unknown########################################

alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']<250) &                            ((alk_OMR['Month']<2) | (alk_OMR['Month']>8)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']<250) &                            ((alk_OMR['Month']<2) | (alk_OMR['Month']>8)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']<250) &                            ((alk_OMR['Month']<3) | (alk_OMR['Month']>7)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']<250) &                            ((alk_OMR['Month']<3) | (alk_OMR['Month']>7)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<3) | (alk_OMR['Month']>7) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']<250) &                            ((alk_OMR['Month']<3) | (alk_OMR['Month']>5)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<3) | (alk_OMR['Month']>5) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<3) | (alk_OMR['Month']>5) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<3) | (alk_OMR['Month']>5) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.162*(alk_OMR['EC'])+9.5



Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']<250) &                           ((Br_OMR['Month']<2) | (Br_OMR['Month']>8)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']<250) &                           ((Br_OMR['Month']<2) | (Br_OMR['Month']>8)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']<250) &                           ((Br_OMR['Month']<3) | (Br_OMR['Month']>7)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']<250) &                           ((Br_OMR['Month']<3) | (Br_OMR['Month']>7)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<3) | (Br_OMR['Month']>7) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']<250) &                           ((Br_OMR['Month']<3) | (Br_OMR['Month']>5)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<3) | (Br_OMR['Month']>5) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<3) | (Br_OMR['Month']>5) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<3) | (Br_OMR['Month']>5) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000458*(Br_OMR['EC']) -0.05



Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']<250) &                           ((Ca_OMR['Month']<2) | (Ca_OMR['Month']>8)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']<250) &                           ((Ca_OMR['Month']<2) | (Ca_OMR['Month']>8)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']<250) &                           ((Ca_OMR['Month']<3) | (Ca_OMR['Month']>7)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']<250) &                           ((Ca_OMR['Month']<3) | (Ca_OMR['Month']>7)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<3) | (Ca_OMR['Month']>7) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']<250) &                           ((Ca_OMR['Month']<3) | (Ca_OMR['Month']>5)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<3) | (Ca_OMR['Month']>5) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<3) | (Ca_OMR['Month']>5) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<3) | (Ca_OMR['Month']>5) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0420*(Ca_OMR['EC'])+ 3.4



Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']<250) &                           ((Cl_OMR['Month']<2) | (Cl_OMR['Month']>8)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']<250) &                           ((Cl_OMR['Month']<2) | (Cl_OMR['Month']>8)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']<250) &                           ((Cl_OMR['Month']<3) | (Cl_OMR['Month']>7)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']<250) &                           ((Cl_OMR['Month']<3) | (Cl_OMR['Month']>7)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<3) | (Cl_OMR['Month']>7) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']<250) &                           ((Cl_OMR['Month']<3) | (Cl_OMR['Month']>5)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<3) | (Cl_OMR['Month']>5) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<3) | (Cl_OMR['Month']>5) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<3) | (Cl_OMR['Month']>5) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['simulated'].isnull()), 'simulated'] =6.50E-06*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.147*(Cl_OMR['EC']) - 12.5



K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']<250) &                               ((K_OMR['Month']<2) | (K_OMR['Month']>8)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']<250) &                               ((K_OMR['Month']<2) | (K_OMR['Month']>8)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']<250) &                               ((K_OMR['Month']<3) | (K_OMR['Month']>7)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']<250) &                               ((K_OMR['Month']<3) | (K_OMR['Month']>7)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<3) | (K_OMR['Month']>7) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']<250) &                               ((K_OMR['Month']<3) | (K_OMR['Month']>5)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<3) | (K_OMR['Month']>5) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<3) | (K_OMR['Month']>5) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<3) | (K_OMR['Month']>5) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['simulated'].isnull()), 'simulated'] =3.78E-07*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00232*(K_OMR['EC'])+ 1.0


Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']<250) &                            ((Mg_OMR['Month']<2) | (Mg_OMR['Month']>8)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']<250) &                            ((Mg_OMR['Month']<2) | (Mg_OMR['Month']>8)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']<250) &                            ((Mg_OMR['Month']<3) | (Mg_OMR['Month']>7)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']<250) &                            ((Mg_OMR['Month']<3) | (Mg_OMR['Month']>7)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<3) | (Mg_OMR['Month']>7) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']<250) &                            ((Mg_OMR['Month']<3) | (Mg_OMR['Month']>5)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<3) | (Mg_OMR['Month']>5) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<3) | (Mg_OMR['Month']>5) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<3) | (Mg_OMR['Month']>5) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0232*(Mg_OMR['EC'])+ 0.5



Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<2) | (Na_OMR['Month']>8)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<2) | (Na_OMR['Month']>8)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<3) | (Na_OMR['Month']>7)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<3) | (Na_OMR['Month']>7)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<3) | (Na_OMR['Month']>7) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<3) | (Na_OMR['Month']>5)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<3) | (Na_OMR['Month']>5) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<3) | (Na_OMR['Month']>5) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<3) | (Na_OMR['Month']>5) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.110*(Na_OMR['EC']) -3.9


SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']<250) & ((SO4_OMR['Month']<2) | (SO4_OMR['Month']>8)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) & (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']<250) & ((SO4_OMR['Month']<2) | (SO4_OMR['Month']>8)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) & (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']<250) & ((SO4_OMR['Month']<3) | (SO4_OMR['Month']>7)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']<250) & ((SO4_OMR['Month']<3) | (SO4_OMR['Month']>7)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>7) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']<250) & ((SO4_OMR['Month']<3) | (SO4_OMR['Month']>5)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>5) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<3) | (SO4_OMR['Month']>5) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<3) | (SO4_OMR['Month']>5) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0917*(SO4_OMR['EC'])+ 3.8


TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<2) | (TDS_OMR['Month']>8)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<2) | (TDS_OMR['Month']>8)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<3) | (TDS_OMR['Month']>7)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<3) | (TDS_OMR['Month']>7)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<3) | (TDS_OMR['Month']>7) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<3) | (TDS_OMR['Month']>5)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<3) | (TDS_OMR['Month']>5) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<3) | (TDS_OMR['Month']>5) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<3) | (TDS_OMR['Month']>5) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.526*(TDS_OMR['EC'])+ 11.3

# %%
##################Old-Middle River Export Corridor Subregion#######################
###################X2 position is known########################################



alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']<250) &                           ((alk_OMR['Month']<2) | (alk_OMR['Month']>8)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'W') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']<250) &                           ((alk_OMR['Month']<2) | (alk_OMR['Month']>8)) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250) &     (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500) &   (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'AN') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000) & (alk_OMR['Month']<2) | (alk_OMR['Month']>8) , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']<250)                             , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250)      , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500)    , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'BN') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000)  , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']<250)                             , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250)      , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500)    , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'D') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000)  , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']<250)                             , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.205*(alk_OMR['EC'])+15.0
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']<1000) &(alk_OMR['EC']>=250)      , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.00280*(alk_OMR['EC'])+61.9
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']>=1000) &(alk_OMR['EC']<17500)    , 'simulated'] = -1.13E-08*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.00168*(alk_OMR['EC'])+61.5
alk_OMR.loc[(alk_OMR['WYT'] == 'C') & (alk_OMR['EC']>=17500) & (alk_OMR['EC']<53000)  , 'simulated'] = 0*(alk_OMR['EC'])*(alk_OMR['EC']) + 0.000950*(alk_OMR['EC'])+66.0

alk_OMR.loc[(alk_OMR['simulated'].isnull()), 'simulated'] =-4.01E-05*(alk_OMR['EC'])*(alk_OMR['EC'])+ 0.162*(alk_OMR['EC'])+9.5



Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']<250) &                          ((Br_OMR['Month']<2) | (Br_OMR['Month']>8)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'W') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']<250) &                          ((Br_OMR['Month']<2) | (Br_OMR['Month']>8)) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250) &    (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500) &  (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'AN') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000) & (Br_OMR['Month']<2) | (Br_OMR['Month']>8) , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']<250)                            , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250)     , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500)   , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'BN') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000)  , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']<250)                             , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250)      , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500)    , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'D') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000)   , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']<250)                             , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000401*(Br_OMR['EC']) - 0.03
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']<1000) & (Br_OMR['EC']>=250)      , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000869*(Br_OMR['EC']) - 0.13
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']>=1000) & (Br_OMR['EC']<17500)    , 'simulated'] = 3.21E-10*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00114*(Br_OMR['EC']) - 0.46
Br_OMR.loc[(Br_OMR['WYT'] == 'C') & (Br_OMR['EC']>=17500) & (Br_OMR['EC']<53000)   , 'simulated'] = 0*(Br_OMR['EC'])*(Br_OMR['EC']) + 0.00123*(Br_OMR['EC']) - 0.24

Br_OMR.loc[(Br_OMR['simulated'].isnull()), 'simulated'] =2.70E-08*(Br_OMR['EC'])*(Br_OMR['EC'])+ 0.000458*(Br_OMR['EC']) -0.05



Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']<250) &                          ((Ca_OMR['Month']<2) | (Ca_OMR['Month']>8)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'W') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']<250) &                          ((Ca_OMR['Month']<2) | (Ca_OMR['Month']>8)) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250) &    (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500) &  (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'AN') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000) & (Ca_OMR['Month']<2) | (Ca_OMR['Month']>8) , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']<250)                             , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250)      , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500)    , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'BN') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000)   , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']<250)                             , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250)      , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500)    , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'D') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000)   , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']<250)                             , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0422*(Ca_OMR['EC'])+4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']<1000) & (Ca_OMR['EC']>=250)      , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.00482*(Ca_OMR['EC'])+12.4
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']>=1000) & (Ca_OMR['EC']<17500)    , 'simulated'] = 5.06E-08*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00619*(Ca_OMR['EC'])+10.9
Ca_OMR.loc[(Ca_OMR['WYT'] == 'C') & (Ca_OMR['EC']>=17500) & (Ca_OMR['EC']<53000)   , 'simulated'] = 0*(Ca_OMR['EC'])*(Ca_OMR['EC']) + 0.00735*(Ca_OMR['EC'])+12.7

Ca_OMR.loc[(Ca_OMR['simulated'].isnull()), 'simulated'] =2.41E-06*(Ca_OMR['EC'])*(Ca_OMR['EC'])+ 0.0420*(Ca_OMR['EC'])+ 3.4



Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']<250) &                          ((Cl_OMR['Month']<2) | (Cl_OMR['Month']>8)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'W') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']<250) &                          ((Cl_OMR['Month']<2) | (Cl_OMR['Month']>8)) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250) &    (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500) &  (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'AN') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000) & (Cl_OMR['Month']<2) | (Cl_OMR['Month']>8) , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']<250)                             , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250)      , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500)    , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'BN') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000)   , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']<250)                             , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250)      , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500)    , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'D') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000)   , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']<250)                             , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.139*(Cl_OMR['EC'])-10.9
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']<1000) & (Cl_OMR['EC']>=250)      , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.282*(Cl_OMR['EC']) - 45.1
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']>=1000) & (Cl_OMR['EC']<17500)    , 'simulated'] = 2.42E-06*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.299*(Cl_OMR['EC'])-72.5
Cl_OMR.loc[(Cl_OMR['WYT'] == 'C') & (Cl_OMR['EC']>=17500) & (Cl_OMR['EC']<53000)   , 'simulated'] = 0*(Cl_OMR['EC'])*(Cl_OMR['EC']) + 0.364*(Cl_OMR['EC']) - 67.3

Cl_OMR.loc[(Cl_OMR['simulated'].isnull()), 'simulated'] =6.50E-06*(Cl_OMR['EC'])*(Cl_OMR['EC'])+ 0.147*(Cl_OMR['EC']) - 12.5



K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']<250) &                              ((K_OMR['Month']<2) | (K_OMR['Month']>8)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'W') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']<250) &                              ((K_OMR['Month']<2) | (K_OMR['Month']>8)) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250) &         (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500) &       (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'AN') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000) &      (K_OMR['Month']<2) | (K_OMR['Month']>8) , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']<250)                                 , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250)           , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500)         , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'BN') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000)        , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']<250)                                 , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250)           , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500)         , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'D') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000)        , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']<250)                                 , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00484*(K_OMR['EC'])+0.6
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']<1000) & (K_OMR['EC']>=250)           , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00583*(K_OMR['EC'])+0.5
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']>=1000) & (K_OMR['EC']<17500)         , 'simulated'] = 5.01E-08*(K_OMR['EC'])*(K_OMR['EC']) + 0.0062*(K_OMR['EC'])-0.614
K_OMR.loc[(K_OMR['WYT'] == 'C') & (K_OMR['EC']>=17500) & (K_OMR['EC']<53000)        , 'simulated'] = 0*(K_OMR['EC'])*(K_OMR['EC']) + 0.00729*(K_OMR['EC'])+0

K_OMR.loc[(K_OMR['simulated'].isnull()), 'simulated'] =3.78E-07*(K_OMR['EC'])*(K_OMR['EC'])+ 0.00232*(K_OMR['EC'])+ 1.0


Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']<250) &                           ((Mg_OMR['Month']<2) | (Mg_OMR['Month']>8)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'W') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']<250) &                           ((Mg_OMR['Month']<2) | (Mg_OMR['Month']>8)) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250) &     (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500) &   (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'AN') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000) &  (Mg_OMR['Month']<2) | (Mg_OMR['Month']>8) , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']<250)                              , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250)       , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500)     , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'BN') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000)    , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']<250)                              , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250)       , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500)     , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'D') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000)    , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']<250)                             , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0355*(Mg_OMR['EC'])+0.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']<1000) & (Mg_OMR['EC']>=250)      , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0188*(Mg_OMR['EC'])+4.1
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']>=1000) & (Mg_OMR['EC']<17500)    , 'simulated'] = 9.13E-08*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0207*(Mg_OMR['EC'])-0.4
Mg_OMR.loc[(Mg_OMR['WYT'] == 'C') & (Mg_OMR['EC']>=17500) & (Mg_OMR['EC']<53000)   , 'simulated'] = 0*(Mg_OMR['EC'])*(Mg_OMR['EC']) + 0.0244*(Mg_OMR['EC'])+2.9

Mg_OMR.loc[(Mg_OMR['simulated'].isnull()), 'simulated'] =2.44E-06*(Mg_OMR['EC'])*(Mg_OMR['EC'])+ 0.0232*(Mg_OMR['EC'])+ 0.5



Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<2) | (Na_OMR['Month']>8)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'W') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']<250) &                          ((Na_OMR['Month']<2) | (Na_OMR['Month']>8)) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250) &    (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500) &  (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'AN') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000) & (Na_OMR['Month']<2) | (Na_OMR['Month']>8) , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']<250)                             , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250)      , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500)    , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'BN') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000)   , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']<250)                             , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250)      , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500)    , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'D') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000)   , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']<250)                            , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.102*(Na_OMR['EC'])-4.9
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']<1000) & (Na_OMR['EC']>=250)     , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.155*(Na_OMR['EC'])-16.8
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']>=1000) & (Na_OMR['EC']<17500)   , 'simulated'] = 1.16E-06*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.163*(Na_OMR['EC'])-35.0
Na_OMR.loc[(Na_OMR['WYT'] == 'C') & (Na_OMR['EC']>=17500) & (Na_OMR['EC']<53000)  , 'simulated'] = 0*(Na_OMR['EC'])*(Na_OMR['EC']) + 0.202*(Na_OMR['EC'])-22.9

Na_OMR.loc[(Na_OMR['simulated'].isnull()), 'simulated'] =1.24E-05*(Na_OMR['EC'])*(Na_OMR['EC'])+ 0.110*(Na_OMR['EC']) -3.9


SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']<250) &                            ((SO4_OMR['Month']<2) | (SO4_OMR['Month']>8)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) &     (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &   (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'W') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) &  (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']<250) &                           ((SO4_OMR['Month']<2) | (SO4_OMR['Month']>8)) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250) &    (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500) &  (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'AN') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000) & (SO4_OMR['Month']<2) | (SO4_OMR['Month']>8) , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']<250)                              , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250)      , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500)    , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'BN') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000)   , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']<250)                               , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250)       , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500)     , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'D') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000)    , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']<250)                               , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0716*(SO4_OMR['EC'])-1.0
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']<1000) & (SO4_OMR['EC']>=250)       , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0342*(SO4_OMR['EC'])+8.9
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']>=1000) & (SO4_OMR['EC']<17500)     , 'simulated'] = 3.60E-07*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0400*(SO4_OMR['EC'])+1.3
SO4_OMR.loc[(SO4_OMR['WYT'] == 'C') & (SO4_OMR['EC']>=17500) & (SO4_OMR['EC']<53000)    , 'simulated'] = 0*(SO4_OMR['EC'])*(SO4_OMR['EC']) + 0.0510*(SO4_OMR['EC'])+4.2

SO4_OMR.loc[(SO4_OMR['simulated'].isnull()), 'simulated'] =4.76E-05*(SO4_OMR['EC'])*(SO4_OMR['EC'])+ 0.0917*(SO4_OMR['EC'])+ 3.8


TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<2) | (TDS_OMR['Month']>8)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'W') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']<250) &                           ((TDS_OMR['Month']<2) | (TDS_OMR['Month']>8)) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250) &    (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500) &  (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'AN') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000) & (TDS_OMR['Month']<2) | (TDS_OMR['Month']>8) , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']<250)                              , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250)      , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500)    , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'BN') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000)   , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']<250)                             , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250)      , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500)    , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'D') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000)   , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']<250)                              , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.593*(TDS_OMR['EC'])+0.8
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']<1000) & (TDS_OMR['EC']>=250)      , 'simulated'] = 0*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.527*(TDS_OMR['EC'])+13.3
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']>=1000) & (TDS_OMR['EC']<17500)    , 'simulated'] = 4.84E-06*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.544*(TDS_OMR['EC'])-20.9
TDS_OMR.loc[(TDS_OMR['WYT'] == 'C') & (TDS_OMR['EC']>=17500) & (TDS_OMR['EC']<53000)   , 'simulated'] =0*(TDS_OMR['EC'])*(TDS_OMR['EC']) + 0.659*(TDS_OMR['EC'])-15.8

TDS_OMR.loc[(TDS_OMR['simulated'].isnull()), 'simulated'] =5.73E-05*(TDS_OMR['EC'])*(TDS_OMR['EC'])+ 0.526*(TDS_OMR['EC'])+ 11.3

# %%
sns.heatmap(Br_south.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
print('*******************South Delta Subregion***************')

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from scipy.stats import sem

print("TDS:        ","R2 =",round(r2_score(TDS_south['TDS'],TDS_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(TDS_south['simulated'],TDS_south['TDS']),ndigits=2), "   MSE =", round(mean_squared_error(TDS_south['simulated'],TDS_south['TDS']),ndigits=2),"   SE =" ,round(sem(TDS_south['simulated']),ndigits=2))
print("Br:         ","R2 =",round(r2_score(Br_south['Br'],Br_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Br_south['simulated'],Br_south['Br']),ndigits=2), "   MSE =", round(mean_squared_error(Br_south['simulated'],Br_south['Br']),ndigits=2),"      SE =" ,round(sem(Br_south['simulated']),ndigits=2))
print("Cl:         ","R2 =",round(r2_score(Cl_south['Cl'],Cl_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Cl_south['simulated'],Cl_south['Cl']),ndigits=2), "   MSE =", round(mean_squared_error(Cl_south['simulated'],Cl_south['Cl']),ndigits=2),"   SE =" ,round(sem(Cl_south['simulated']),ndigits=2))
print("SO4:        ","R2 =",round(r2_score(SO4_south['SO4'],SO4_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(SO4_south['simulated'],SO4_south['SO4']),ndigits=2), "  MSE =", round(mean_squared_error(SO4_south['simulated'],SO4_south['SO4']),ndigits=2),"   SE =" ,round(sem(SO4_south['simulated']),ndigits=2))
print("Alkalinity: ","R2 =",round(r2_score(alk_south['Alkalinity'],alk_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(alk_south['simulated'],alk_south['Alkalinity']),ndigits=2), "   MSE =", round(mean_squared_error(alk_south['simulated'],alk_south['Alkalinity']),ndigits=2),"     SE =" ,round(sem(alk_south['simulated']),ndigits=2))
print("Na:         ","R2 =",round(r2_score(Na_south['Na'],Na_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Na_south['simulated'],Na_south['Na']),ndigits=2), "   MSE =", round(mean_squared_error(Na_south['simulated'],Na_south['Na']),ndigits=2),"    SE =" ,round(sem(Na_south['simulated']),ndigits=2))
print("Ca:         ","R2 =",round(r2_score(Ca_south['Ca'],Ca_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Ca_south['simulated'],Ca_south['Ca']),ndigits=2), "   MSE =", round(mean_squared_error(Ca_south['simulated'],Ca_south['Ca']),ndigits=2),"    SE =" ,round(sem(Ca_south['simulated']),ndigits=2))
print("Mg:         ","R2 =",round(r2_score(Mg_south['Mg'],Mg_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Mg_south['simulated'],Mg_south['Mg']),ndigits=2), "   MSE =", round(mean_squared_error(Mg_south['simulated'],Mg_south['Mg']),ndigits=2),"     SE =" ,round(sem(Mg_south['simulated']),ndigits=2))
print("K:          ","R2 =",round(r2_score(K_south['K'],K_south['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(K_south['simulated'],K_south['K']),ndigits=2), "    MSE =", round(mean_squared_error(K_south['simulated'],K_south['K']),ndigits=2),"     SE =" ,round(sem(K_south['simulated']),ndigits=2))

# %%
print('*******************San Joaquin River Corridor Subregion***************')

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from scipy.stats import sem

print("TDS:        ","R2 =",round(r2_score(TDS_SJ['TDS'],TDS_SJ['simulated']),ndigits=3),"   MAE =", round(mean_absolute_error(TDS_SJ['simulated'],TDS_SJ['TDS']),ndigits=2), "  MSE =", round(mean_squared_error(TDS_SJ['simulated'],TDS_SJ['TDS']),ndigits=2),"    SE =" ,round(sem(TDS_SJ['simulated']),ndigits=2))
print("Br:         ","R2 =",round(r2_score(Br_SJ['Br'],Br_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Br_SJ['simulated'],Br_SJ['Br']),ndigits=2), "  MSE =", round(mean_squared_error(Br_SJ['simulated'],Br_SJ['Br']),ndigits=2),"         SE =" ,round(sem(Br_SJ['simulated']),ndigits=2))
print("Cl:         ","R2 =",round(r2_score(Cl_SJ['Cl'],Cl_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Cl_SJ['simulated'],Cl_SJ['Cl']),ndigits=2), "  MSE =", round(mean_squared_error(Cl_SJ['simulated'],Cl_SJ['Cl']),ndigits=2),"     SE =" ,round(sem(Cl_SJ['simulated']),ndigits=2))
print("SO4:        ","R2 =",round(r2_score(SO4_SJ['SO4'],SO4_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(SO4_SJ['simulated'],SO4_SJ['SO4']),ndigits=2), "  MSE =", round(mean_squared_error(SO4_SJ['simulated'],SO4_SJ['SO4']),ndigits=2),"      SE =" ,round(sem(SO4_SJ['simulated']),ndigits=2))
print("Alkalinity: ","R2 =",round(r2_score(alk_SJ['Alkalinity'],alk_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(alk_SJ['simulated'],alk_SJ['Alkalinity']),ndigits=2), "  MSE =", round(mean_squared_error(alk_SJ['simulated'],alk_SJ['Alkalinity']),ndigits=2),"    SE =" ,round(sem(alk_SJ['simulated']),ndigits=2))
print("Na:         ","R2 =",round(r2_score(Na_SJ['Na'],Na_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Na_SJ['simulated'],Na_SJ['Na']),ndigits=2), "  MSE =", round(mean_squared_error(Na_SJ['simulated'],Na_SJ['Na']),ndigits=2),"      SE =" ,round(sem(Na_SJ['simulated']),ndigits=2))
print("Ca:         ","R2 =",round(r2_score(Ca_SJ['Ca'],Ca_SJ['simulated']),ndigits=3),"   MAE =", round(mean_absolute_error(Ca_SJ['simulated'],Ca_SJ['Ca']),ndigits=2), "  MSE =", round(mean_squared_error(Ca_SJ['simulated'],Ca_SJ['Ca']),ndigits=2),"     SE =" ,round(sem(Ca_SJ['simulated']),ndigits=2))
print("Mg:         ","R2 =",round(r2_score(Mg_SJ['Mg'],Mg_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Mg_SJ['simulated'],Mg_SJ['Mg']),ndigits=2), "  MSE =", round(mean_squared_error(Mg_SJ['simulated'],Mg_SJ['Mg']),ndigits=2),"      SE =" ,round(sem(Mg_SJ['simulated']),ndigits=2))
print("K:          ","R2 =",round(r2_score(K_SJ['K'],K_SJ['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(K_SJ['simulated'],K_SJ['K']),ndigits=2), "  MSE =", round(mean_squared_error(K_SJ['simulated'],K_SJ['K']),ndigits=2),"      SE =" ,round(sem(K_SJ['simulated']),ndigits=2))

# %%
print('*******************Old-Middle River Export Corridor Subregion***************')

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


print("TDS:        ","R2 =",round(r2_score(TDS_OMR['TDS'],TDS_OMR['simulated']),ndigits=3),"   MAE =", round(mean_absolute_error(TDS_OMR['simulated'],TDS_OMR['TDS']),ndigits=2), "  MSE =", round(mean_squared_error(TDS_OMR['simulated'],TDS_OMR['TDS']),ndigits=2),"  SE =" ,round(sem(TDS_OMR['simulated']),ndigits=2))
print("Br:         ","R2 =",round(r2_score(Br_OMR['Br'],Br_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Br_OMR['simulated'],Br_OMR['Br']),ndigits=2), "  MSE =", round(mean_squared_error(Br_OMR['simulated'],Br_OMR['Br']),ndigits=2),"        SE =" ,round(sem(Br_OMR['simulated']),ndigits=2))
print("Cl:         ","R2 =",round(r2_score(Cl_OMR['Cl'],Cl_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Cl_OMR['simulated'],Cl_OMR['Cl']),ndigits=2), "  MSE =", round(mean_squared_error(Cl_OMR['simulated'],Cl_OMR['Cl']),ndigits=2),"   SE =" ,round(sem(Cl_OMR['simulated']),ndigits=2))
print("SO4:        ","R2 =",round(r2_score(SO4_OMR['SO4'],SO4_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(SO4_OMR['simulated'],SO4_OMR['SO4']),ndigits=2), "  MSE =", round(mean_squared_error(SO4_OMR['simulated'],SO4_OMR['SO4']),ndigits=2),"     SE =" ,round(sem(SO4_OMR['simulated']),ndigits=2))
print("Alkalinity: ","R2 =",round(r2_score(alk_OMR['Alkalinity'],alk_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(alk_OMR['simulated'],alk_OMR['Alkalinity']),ndigits=2), "  MSE =", round(mean_squared_error(alk_OMR['simulated'],alk_OMR['Alkalinity']),ndigits=2),"    SE =" ,round(sem(alk_OMR['simulated']),ndigits=2))
print("Na:         ","R2 =",round(r2_score(Na_OMR['Na'],Na_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Na_OMR['simulated'],Na_OMR['Na']),ndigits=2), "  MSE =", round(mean_squared_error(Na_OMR['simulated'],Na_OMR['Na']),ndigits=2),"    SE =" ,round(sem(Na_OMR['simulated']),ndigits=2))
print("Ca:         ","R2 =",round(r2_score(Ca_OMR['Ca'],Ca_OMR['simulated']),ndigits=3),"   MAE =", round(mean_absolute_error(Ca_OMR['simulated'],Ca_OMR['Ca']),ndigits=2), "  MSE =", round(mean_squared_error(Ca_OMR['simulated'],Ca_OMR['Ca']),ndigits=2),"     SE =" ,round(sem(Ca_OMR['simulated']),ndigits=2))
print("Mg:         ","R2 =",round(r2_score(Mg_OMR['Mg'],Mg_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(Mg_OMR['simulated'],Mg_OMR['Mg']),ndigits=2), "  MSE =", round(mean_squared_error(Mg_OMR['simulated'],Mg_OMR['Mg']),ndigits=2),"       SE =" ,round(sem(Mg_OMR['simulated']),ndigits=2))
print("K:          ","R2 =",round(r2_score(K_OMR['K'],K_OMR['simulated']),ndigits=3),"  MAE =", round(mean_absolute_error(K_OMR['simulated'],K_OMR['K']),ndigits=2), "  MSE =", round(mean_squared_error(K_OMR['simulated'],K_OMR['K']),ndigits=2),"       SE =" ,round(sem(K_OMR['simulated']),ndigits=2))
